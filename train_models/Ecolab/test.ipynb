# %%
import pandas as pd

# %%
df_R = pd.read_csv('../datas/ECOLAB_4/C4/C4_all.csv' , sep=',')

# %%
df_R.columns
# Out:
# Index(['TEMPERATURE_MEG_FROID [R]', 'TEMPERATURE_MEG_CHAUD [R]',
#        'BP_R134_EN_BARS [R]', 'BP_R134_EN_DEGRES [R]',
#        'CONSIGNE_BALLON_FROID [R]', 'CONSIGNE_BALLON_CHAUD [R]',
#        'HP_R134_EN_BARS [R]', 'HP_R134_EN_DEGRES [R]', 'datatime',
#        'CDE_CONDENSEUR [B]', 'CDE_EVAPORATEUR [B]', 'LOCAL_DISTANT [B]',
#        'MA_THERMO [B]', 'CDE_DEGIVRAGE [B]', 'CDE_EVAPO_FROID [B]',
#        'CDE_EVAPO_CHAUD [B]', 'DEBIT_BP [B]', 'DEBIT_HP [B]',
#        'DEFAUT_COMPRESSEUR_HP [B]', 'DEFAUT_COMPRESSEUR_BP [B]',
#        'DEFAUT_COMPRESSEUR_1 [B]', 'DEFAUT_COMPRESSEUR_2 [B]',
#        'SECURITE_GENERALE [B]', 'THERMOSTAT [B]', 'SECURITE_HP [B]',
#        'COMPRESSEUR_1 [B]', 'COMPRESSEUR_2 [B]', 'CDE_EVAPO_BP_FROID [B]',
#        'CDE_VENTILATEUR_EVAPO [B]', 'POMPE_MEG_FROID [B]',
#        'POMPE_MEG_CHAUD [B]', 'RETOUR_LOCAL_DISTANT [B]',
#        'SECU_BALLON_CHAUD [B]', 'SECU_BALLON_FROID [B]',
#        'CDE_COMPRESSEUR1 [B]', 'CDE_COMPRESSEUR2 [B]', 'datetime'],
#       dtype='object')

# %%
df = df_R.iloc[0:]
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))

# Mapper une couleur par cluster
colors = df['D'].map({0: 'red', 1: 'green'})
#colors_2 = df[''].map({1: 'purple', 0: 'brown'})
#colors_3 = df['cluster'].map({1: 'purple', 0: 'brown'})
#colors_4 = df['cluster'].map({1: 'yellow', 0: 'white'})

# Tracer chaque variable (sur le même graphique) avec la couleur correspondant au cluster

#plt.scatter(df.index, df['TEMPERATURE_MOY_INF [R]'], c=colors, label='Prob-Reprise', alpha=1.0, s=2)
#plt.scatter(df.index, df['TEMPERATURE_MOY_SUP [R]'], c=colors_2, label='Prob-Consigne', alpha=1.0, s=2)

plt.scatter(df.index, df['TEMPERATURE_MEG_FROID [R]'], c=colors, label='Normal', alpha=0.5, s=2)
plt.scatter(df.index, df['CONSIGNE_BALLON_FROID [R]'], c=colors, label='Normal', alpha=0.5, s=2)
#plt.scatter(df.index, df['TEMPERATURE_MOY_INF [R]'], c=colors_3, label='Prob-Consigne', alpha=1.0, s=2)
#plt.scatter(df.index, df['alerte_pred'], c=colors_4, label='Prob-Consigne', alpha=1.0, s=2)
plt.title('TEMPERATURE_MEG_FROID [R] +CONSIGNE_BALLON_FROID [R] ')
plt.xlabel(df['datetime'])
plt.ylabel('CDE_EVAPO_FROID [B] ' )
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4755, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4754 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4755     colors = mcolors.to_rgba_array(c)
#    4756 except (TypeError, ValueError) as err:
#
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/colors.py:515, in to_rgba_array(c, alpha)
#     514 else:
# --> 515     rgba = np.array([to_rgba(cc) for cc in c])
#     517 if alpha is not None:
#
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/colors.py:515, in <listcomp>(.0)
#     514 else:
# --> 515     rgba = np.array([to_rgba(cc) for cc in c])
#     517 if alpha is not None:
#
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/colors.py:317, in to_rgba(c, alpha)
#     316 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 317     rgba = _to_rgba_no_colorcycle(c, alpha)
#     318     try:
#
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/colors.py:401, in _to_rgba_no_colorcycle(c, alpha)
#     400 if not np.iterable(c):
# --> 401     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     402 if len(c) not in [3, 4]:
#
# ValueError: Invalid RGBA argument: nan
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 17
#       7 colors = df['HP_R134_EN_DEGRES [R]'].map({0: 'red', 1: 'green'})
#       8 #colors_2 = df[''].map({1: 'purple', 0: 'brown'})
#       9 #colors_3 = df['cluster'].map({1: 'purple', 0: 'brown'})
#      10 #colors_4 = df['cluster'].map({1: 'yellow', 0: 'white'})
#    (...)     14 #plt.scatter(df.index, df['TEMPERATURE_MOY_INF [R]'], c=colors, label='Prob-Reprise', alpha=1.0, s=2)
#      15 #plt.scatter(df.index, df['TEMPERATURE_MOY_SUP [R]'], c=colors_2, label='Prob-Consigne', alpha=1.0, s=2)
# ---> 17 plt.scatter(df.index, df['TEMPERATURE_MEG_FROID [R]'], c=colors, label='Normal', alpha=0.5, s=2)
#      18 plt.scatter(df.index, df['CONSIGNE_BALLON_FROID [R]'], c=colors, label='Normal', alpha=0.5, s=2)
#      19 #plt.scatter(df.index, df['TEMPERATURE_MOY_INF [R]'], c=colors_3, label='Prob-Consigne', alpha=1.0, s=2)
#      20 #plt.scatter(df.index, df['alerte_pred'], c=colors_4, label='Prob-Consigne', alpha=1.0, s=2)
#
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/pyplot.py:3937, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3917 @_copy_docstring_and_deprecators(Axes.scatter)
#    3918 def scatter(
#    3919     x: float | ArrayLike,
#    (...)   3935     **kwargs,
#    3936 ) -> PathCollection:
# -> 3937     __ret = gca().scatter(
#    3938         x,
#    3939         y,
#    3940         s=s,
#    3941         c=c,
#    3942         marker=marker,
#    3943         cmap=cmap,
#    3944         norm=norm,
#    3945         vmin=vmin,
#    3946         vmax=vmax,
#    3947         alpha=alpha,
#    3948         linewidths=linewidths,
#    3949         edgecolors=edgecolors,
#    3950         colorizer=colorizer,
#    3951         plotnonfinite=plotnonfinite,
#    3952         **({"data": data} if data is not None else {}),
#    3953         **kwargs,
#    3954     )
#    3955     sci(__ret)
#    3956     return __ret
#
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4948, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4945 if edgecolors is None:
#    4946     orig_edgecolor = kwargs.get('edgecolor', None)
#    4947 c, colors, edgecolors = \
# -> 4948     self._parse_scatter_color_args(
#    4949         c, edgecolors, kwargs, x.size,
#    4950         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4952 if plotnonfinite and colors is None:
#    4953     c = np.ma.masked_invalid(c)
#
# File ~/octobrain/.venv/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4764, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4761             raise invalid_shape_exception(c.size, xsize) from err
#    4762         # Both the mapping *and* the RGBA conversion failed: pretty
#    4763         # severe failure => one may appreciate a verbose feedback.
# -> 4764         raise ValueError(
#    4765             f"'c' argument must be a color, a sequence of colors, "
#    4766             f"or a sequence of numbers, not {c!r}") from err
#    4767 else:
#    4768     if len(colors) not in (0, 1, xsize):
#    4769         # NB: remember that a single color is also acceptable.
#    4770         # Besides *colors* will be an empty array if c == 'none'.
#
# ValueError: 'c' argument must be a color, a sequence of colors, or a sequence of numbers, not 0         red
# 1         red
# 2         red
# 3         NaN
# 4         NaN
#          ...
# 188439    NaN
# 188440    NaN
# 188441    NaN
# 188442    NaN
# 188443    NaN
# Name: HP_R134_EN_DEGRES [R], Length: 188444, dtype: object
