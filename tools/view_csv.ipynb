# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
full_df = pd.read_csv('data/BIOTECA-average_ecolab.csv', sep=';')

# %%
df = full_df.iloc[25_200:27_610]
plt.figure(figsize=(8, 6))
plt.plot(df['E2-C1:temp_set'], color='blue', label='E2-C1:temp_set')
plt.plot(df['E2-C1:temp_cell'], color='red', label='E2-C2:temp_set')
plt.grid(True)
plt.show()

# %%
train_df = full_df.iloc[18_200:24_610]
train_df.to_csv('data/train.csv', index=False,sep=";")

# %%
test_df = full_df.iloc[25_200:26_950]
test_df.to_csv('data/test.csv', index=False, sep=";")
